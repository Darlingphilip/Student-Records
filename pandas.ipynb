# %%
students = {}

# %%
students = {
    "NAME": [
        "ISAAC", "PHILIP", "OLIVER", "DESMOND", "EMMANUEL",
        "DANIEL", "SAMUEL", "MICHAEL", "JOSEPH", "DAVID",
        "RICHARD", "PETER", "STEPHEN", "BENJAMIN", "ANDREW",
        "FELIX", "KWAME", "KOFI", "NANA", "EBENEZER"
    ],

    "AGE": [
        23, 12, 24, 54, 20,
        22, 19, 21, 25, 23,
        24, 20, 22, 21, 26,
        23, 19, 20, 22, 24
    ],

    "MATHS": [
        65, 78, 98, 78, 82,
        91, 74, 69, 88, 95,
        73, 67, 80, 84, 76,
        90, 71, 85, 79, 93
    ],

    "SCIENCE": [
        70, 82, 94, 75, 80,
        89, 72, 71, 90, 92,
        74, 69, 83, 81, 77,
        88, 73, 86, 80, 91
    ],

    "ENGLISH": [
        68, 80, 95, 79, 84,
        90, 76, 73, 87, 94,
        75, 70, 82, 85, 78,
        89, 72, 84, 81, 92
    ],

    "R.M.E": [
        72, 85, 97, 81, 83,
        93, 78, 74, 91, 96,
        76, 71, 84, 87, 80,
        92, 75, 88, 82, 94
    ]
}

# %%
df = pd.DataFrame(students)

# %%
df["TOTAL"] = (
    df["MATHS"] +
    df["SCIENCE"] +
    df["ENGLISH"] +
    df["R.M.E"]
)

# %%
df["AVERAGE"] = df["TOTAL"] / 4

# %%
df["POSITION"] = df["AVERAGE"].rank(
    ascending=False,
    method="min"
).astype(int)

# %%
df = df.sort_values("POSITION")

# %%
df
# Out:
#         NAME  AGE  MATHS  SCIENCE  ENGLISH  R.M.E  TOTAL  AVERAGE  POSITION
# 2     OLIVER   24     98       94       95     97    384    96.00         1
# 9      DAVID   23     95       92       94     96    377    94.25         2
# 19  EBENEZER   24     93       91       92     94    370    92.50         3
# 5     DANIEL   22     91       89       90     93    363    90.75         4
# 15     FELIX   23     90       88       89     92    359    89.75         5
# 8     JOSEPH   25     88       90       87     91    356    89.00         6
# 17      KOFI   20     85       86       84     88    343    85.75         7
# 13  BENJAMIN   21     84       81       85     87    337    84.25         8
# 4   EMMANUEL   20     82       80       84     83    329    82.25         9
# 12   STEPHEN   22     80       83       82     84    329    82.25         9
# 1     PHILIP   12     78       82       80     85    325    81.25        11
# ...
