# %%
students = {}

# %%
students["NAME"] = [
    "ISAAC",
    "PHILIP",
    "OLIVER",
    "DESMOND",
    "EMMANUEL",
    "DANIEL",
    "SAMUEL",
    "MICHAEL",
    "JOSEPH",
    "DAVID",
    "RICHARD",
    "PETER",
    "STEPHEN",
    "BENJAMIN",
    "ANDREW",
    "FELIX",
    "KWAME",
    "KOFI",
    "NANA",
    "EBENEZER"
]

# %%
students["MARKS"] = [
    65, 78, 98, 78, 82,
    91, 74, 69, 88, 95,
    73, 67, 80, 84, 76,
    90, 71, 85, 79, 93
]

# %%
students["AGE"] = [
    23, 12, 24, 54, 20,
    22, 19, 21, 25, 23,
    24, 20, 22, 21, 26,
    23, 19, 20, 22, 24
]

# %%
print(students)
# Out:
# {'NAME': ['ISAAC', 'PHILIP', 'OLIVER', 'DESMOND', 'EMMANUEL', 'DANIEL', 'SAMUEL', 'MICHAEL', 'JOSEPH', 'DAVID', 'RICHARD', 'PETER', 'STEPHEN', 'BENJAMIN', 'ANDREW', 'FELIX', 'KWAME', 'KOFI', 'NANA', 'EBENEZER'], 'MARKS': [65, 78, 98, 78, 82, 91, 74, 69, 88, 95, 73, 67, 80, 84, 76, 90, 71, 85, 79, 93], 'AGE': [23, 12, 24, 54, 20, 22, 19, 21, 25, 23, 24, 20, 22, 21, 26, 23, 19, 20, 22, 24]}

# %%
import pandas as pd

# %%
df = pd.DataFrame(students)

# %%
print(df)
# Out:
#         NAME  MARKS  AGE
# 0      ISAAC     65   23
# 1     PHILIP     78   12
# 2     OLIVER     98   24
# 3    DESMOND     78   54
# 4   EMMANUEL     82   20
# 5     DANIEL     91   22
# 6     SAMUEL     74   19
# 7    MICHAEL     69   21
# 8     JOSEPH     88   25
# 9      DAVID     95   23
# 10   RICHARD     73   24
# 11     PETER     67   20
# 12   STEPHEN     80   22
# 13  BENJAMIN     84   21
# 14    ANDREW     76   26
# 15     FELIX     90   23
# 16     KWAME     71   19
# 17      KOFI     85   20
# 18      NANA     79   22
# 19  EBENEZER     93   24
